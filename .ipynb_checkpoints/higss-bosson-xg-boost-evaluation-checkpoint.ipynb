# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

# %%
higgs_bosson_train = pd.read_csv('train.csv')
higgs_bosson_test = pd.read_csv('test.csv')

X = higgs_bosson_train.drop(columns=['label'])
y = higgs_bosson_train['label']

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Check for correlations and feature importances

# %%
# Check values
print(higgs_bosson_train.describe())

# Check null values
higgs_bosson_train.info()
# Out:
#               label            f0            f1            f2            f3  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.531300      0.991232     -0.006811     -0.000732      0.993825
# std        0.499024      0.564973      1.007311      1.008880      0.595426
# min        0.000000      0.274697     -2.434976     -1.742508      0.003158
# 25%        0.000000      0.592950     -0.745140     -0.871931      0.572091
# 50%        1.000000      0.855385     -0.009794      0.005410      0.888489
# 75%        1.000000      1.234579      0.732370      0.873213      1.291927
# max        1.000000      7.000281      2.431946      1.743236      6.582300
#
#                  f4            f5            f6            f7            f8  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean      -0.008596      0.987553     -0.006254     -0.002803      0.995464
# std        1.006594      0.471304      1.011110      1.010000      1.026840
# min       -1.743944      0.139976     -2.968735     -1.741237      0.000000
# 25%       -0.881750      0.677344     -0.696157     -0.869759      0.000000
# 50%       -0.013527      0.893216     -0.002006     -0.011307      1.086538
# 75%        0.863734      1.170007      0.687194      0.869421      2.173076
# max        1.743102      7.064657      2.969674      1.741454      2.173076
#
#        ...           f18           f19           f20           f21  \
# count  ...  50000.000000  50000.000000  50000.000000  50000.000000
# mean   ...     -0.005375     -0.003756      0.986858      1.031884
# std    ...      1.010671      1.005632      1.393160      0.648316
# min    ...     -2.497265     -1.742691      0.000000      0.125548
# 25%    ...     -0.721686     -0.878138      0.000000      0.790732
# 50%    ...     -0.007956     -0.005259      0.000000      0.894857
# 75%    ...      0.714102      0.863975      3.101961      1.025404
# max    ...      2.498009      1.743372      3.101961     16.601603
#
#                 f22           f23           f24           f25           f26  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       1.022110      1.050021      1.011172      0.974119      1.032028
# std        0.368598      0.162819      0.399989      0.525330      0.361799
# min        0.342015      0.266788      0.319854      0.066392      0.303350
# 25%        0.846140      0.985770      0.768110      0.674527      0.819936
# 50%        0.950145      0.989748      0.917472      0.874691      0.947102
# 75%        1.082497      1.019578      1.141695      1.141194      1.137220
# max        8.940148      3.931808      7.442589     11.994177      6.401313
#
#                 f27
# count  50000.000000
# mean       0.958785
# std        0.311875
# min        0.350939
# 25%        0.769645
# 50%        0.870902
# 75%        1.058376
# max        4.835312
#
# [8 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   50000 non-null  float64
#  1   f0      50000 non-null  float64
#  2   f1      50000 non-null  float64
#  3   f2      50000 non-null  float64
#  4   f3      50000 non-null  float64
#  5   f4      50000 non-null  float64
#  6   f5      50000 non-null  float64
#  7   f6      50000 non-null  float64
#  8   f7      50000 non-null  float64
#  9   f8      50000 non-null  float64
#  10  f9      50000 non-null  float64
#  11  f10     50000 non-null  float64
#  12  f11     50000 non-null  float64
#  13  f12     50000 non-null  float64
#  14  f13     50000 non-null  float64
#  15  f14     50000 non-null  float64
#  16  f15     50000 non-null  float64
#  17  f16     50000 non-null  float64
#  18  f17     50000 non-null  float64
#  19  f18     50000 non-null  float64
#  20  f19     50000 non-null  float64
#  21  f20     50000 non-null  float64
#  22  f21     50000 non-null  float64
#  23  f22     50000 non-null  float64
#  24  f23     50000 non-null  float64
#  25  f24     50000 non-null  float64
#  26  f25     50000 non-null  float64
#  27  f26     50000 non-null  float64
#  28  f27     50000 non-null  float64
# dtypes: float64(29)
# memory usage: 11.1 MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=([16,8]))
matrix = X.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()

# %% [markdown]
# # Model Generalization

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
xgBoost = xgb.XGBClassifier()
xgBoost.fit(X_train, 
            y_train, 
            verbose=True,
            early_stopping_rounds=10,
            eval_metric='auc',
            eval_set=[(X_test, y_test)])
print(f'XGBoost Accuracy: {xgBoost.score(X_test, y_test)}')
# print(f'Cross Val Accuracy: {np.mean(cross_val_score(xgBoost, X_train, y_train, cv=5))}')
# Out:
# [0]	validation_0-auc:0.73213
# [1]	validation_0-auc:0.74682
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-auc:0.75352
# [3]	validation_0-auc:0.75955
# [4]	validation_0-auc:0.76447
# [5]	validation_0-auc:0.76888
# [6]	validation_0-auc:0.77266
# [7]	validation_0-auc:0.77579
# [8]	validation_0-auc:0.77805
# [9]	validation_0-auc:0.77955
# [10]	validation_0-auc:0.78090
# [11]	validation_0-auc:0.78188
# [12]	validation_0-auc:0.78334
# [13]	validation_0-auc:0.78373
# [14]	validation_0-auc:0.78557
# [15]	validation_0-auc:0.78632
# [16]	validation_0-auc:0.78609
# [17]	validation_0-auc:0.78692
# [18]	validation_0-auc:0.78730
# [19]	validation_0-auc:0.78713
# [20]	validation_0-auc:0.78754
# [21]	validation_0-auc:0.78786
# [22]	validation_0-auc:0.78798
# [23]	validation_0-auc:0.78815
# [24]	validation_0-auc:0.78794
# [25]	validation_0-auc:0.78777
# [26]	validation_0-auc:0.78764
# [27]	validation_0-auc:0.78727
# [28]	validation_0-auc:0.78811
# [29]	validation_0-auc:0.78854
# [30]	validation_0-auc:0.78835
# [31]	validation_0-auc:0.78835
# [32]	validation_0-auc:0.78870
# [33]	validation_0-auc:0.78883
# [34]	validation_0-auc:0.78902
# [35]	validation_0-auc:0.78891
# [36]	validation_0-auc:0.78843
# [37]	validation_0-auc:0.78824
# [38]	validation_0-auc:0.78785
# [39]	validation_0-auc:0.78700
# [40]	validation_0-auc:0.78699
# [41]	validation_0-auc:0.78690
# [42]	validation_0-auc:0.78658
# [43]	validation_0-auc:0.78733
# [44]	validation_0-auc:0.78695
# XGBoost Accuracy: 0.7115151515151515

# %%
from sklearn.metrics import confusion_matrix

xgBoost = xgb.XGBClassifier()
xgBoost.fit(X_train, y_train)
generalized_predicted = xgBoost.predict(X_test)
confusionM = confusion_matrix(y_test, generalized_predicted)
sns.heatmap(confusionM, annot=True, xticklabels=['Is Higgs', 'Not Higgs'], yticklabels=['Is Higgs', 'Not Higgs'], fmt='.1f')
# plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Hyperparameter Tuning and CV

# %%
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)
# max_depth: higher = overfit
# max_leaves: higher = overfit

parameters = {
#     'learning_rate': [0.1, 0.20],
#     'max_depth': [2, 3, 5, 10, 15],
#     'max_leaves': [2, 3, 5, 10, 15],
#     'subsample': [None, 0, 1],
#     'colsample_bytree': [None, 0, 1],
#     'colsample_bynode': [None, 0, 1],
#     'colsample_bylevel': [None, 0, 1],
#     'n_estimators': [100, 120, 125, 130]
#     'booster': ['gbtree', 'dart', 'gblinear'],
#     'gamma': [None, 0.5, 1.0],
#     'grow_policy': [None, 'depthwise', 'lossguide']
#     'reg_lambda': [None, 5.0, 10],
#     'reg_alpha': [None, 5.0, 10],
#     'scale_pos_weight': [None, 0.5, 1, 5, 10]
    'min_child_weight': [None, 0.5, 1, 5],
    'max_delta_step': [None, 0.5, 1, 5],
}

test_param = {
    'n_estimators': 145,
    'max_depth': None,
    'max_leaves': None,
    'learning_rate': 0.11,
    'gamma': 0.009, 
    'reg_lambda': 10.0,
    'reg_alpha': 10.0,
    'booster': None,
    'colsample_bynode': None, 
    'colsample_bytree': None, 
    'subsample': None
}

xgBoost = xgb.XGBClassifier(eval_metric=metrics.roc_auc_score, **test_param, n_jobs=-1)
xgBoost.fit(X=X_train, 
            y=y_train, 
            verbose=True)

grid_cv = GridSearchCV(xgBoost, parameters, cv=3)
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric=<function roc_auc_score at 0x000002079E712310>,
#                                      feature_types=None, gamma=0.009,
#                                      grow_policy=None, importance_type=None,
#                                      interact...
#                                      learning_rate=0.11, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=145,
#                                      n_jobs=-1, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'max_delta_step': [None, 0.5, 1, 5],
#                          'min_child_weight': [None, 0.5, 1, 5]})

# %%
best_params = grid_cv.best_params_
best_params
# Out:
# {'max_delta_step': None, 'min_child_weight': 5}

# %%
# testing early stopping
test_param = {
    'n_estimators': 200,
    'max_depth': None,
    'max_leaves': None,
    'learning_rate': 0.11,
    'gamma': 0.009, 
    'reg_lambda': 10,
    'reg_alpha': 10,
    'booster': None,
    'colsample_bylevel': None,
    'colsample_bynode': None, 
    'colsample_bytree': None, 
    'subsample': None,
    'scale_pos_weight': None,
    'min_child_weight': None,
#     'max_delta_step': 15,
}
xgBoost = xgb.XGBClassifier(**test_param,n_jobs=-1)
xgBoost.fit(X=X_train, y=y_train, verbose=True)

pred = xgBoost.predict_proba(X_test)[:,1]

# Compute AUROC.
val = metrics.roc_auc_score(y_test, pred)
print(f'Validation AUROC: {val}' )
# Validation AUROC: 0.7941273339567307 0.225
# Validation AUROC: 0.79435247917274 0.2
# Validation AUROC: 0.7953524608236409 0.15
# Validation AUROC: 0.7958104581722846 0.125
# Validation AUROC: 0.7973011970987656 0.115
# Validation AUROC: 0.7977954943934652 0.11,
# Validation AUROC: 0.7961293106444067 0.1

# Validation AUROC: 0.7981917774087899 learn 0.11 and estimator 150
# Validation AUROC: 0.7981917995339093
# Validation AUROC: 0.7979843322883786

# Validation AUROC: 0.7987855934909903


# Validation AUROC: 0.7988415700433198
# Validation AUROC: 0.799169545439715
# Validation AUROC: 0.7995950041126172
# Validation AUROC: 0.8001981496202062
# Out:
# Validation AUROC: 0.8001981496202062

# %%
xgBoost = xgb.XGBClassifier(**test_param)
xgBoost.fit(X_train, y_train)
generalized_predicted = xgBoost.predict(X_test)
confusionM = confusion_matrix(y_test, generalized_predicted)
sns.heatmap(confusionM, annot=True, xticklabels=['Is Higgs', 'Not Higgs'], yticklabels=['Is Higgs', 'Not Higgs'], fmt='.1f')
# Out:
# <AxesSubplot:>

# %%
xgBoost.score(X_test, y_test)
# Out:
# 0.7196363636363636

# %% [markdown]
# # Submission

# %%
train_csv = pd.read_csv('train.csv')

X_valid = train_csv[40000:]
X_train = train_csv[:40000]
y_train = X_train['label']
y_valid = X_valid['label']
X_valid = X_valid.drop(columns='label')
X_train = X_train.drop(columns='label')

y_valid.shape
xgBoost = xgb.XGBClassifier(**test_param)
xgBoost.fit(X_train, y_train)

pred = xgBoost.predict_proba(X_valid)[:,1]

# Compute AUROC.
val = metrics.roc_auc_score(y_valid, pred)
print(f'Validation AUROC: {val}' )

# Plot ROC curve.
fpr, tpr, thresholds = metrics.roc_curve(y_valid, pred)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], color='k', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# Validation AUROC: 0.787893727375871
# 0.7907767360280327
# Out:
# Validation AUROC: 0.7986247922503595
# Text(0, 0.5, 'True Positive Rate')

# %%
pred = xgBoost.predict_proba(higgs_bosson_test)[:,1:2]
submission_test = higgs_bosson_test.copy()

submission = np.hstack((np.arange(submission_test.shape[0]).reshape(-1,1), pred)) # Add Id column.
np.savetxt(fname='submission.csv', X=submission, header='Id,Predicted', delimiter=',', comments='')
